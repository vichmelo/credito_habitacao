# %% [markdown]
# # CONSOLIDAR FICHEIROS DIÁRIOS Rec_CH - GL_EXTRACT

# %%
import os
import pandas as pd

# %%
path = r'C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files'
files = os.listdir(path)
df = pd.DataFrame()

print(files)
# Out:
# ['Rec_CH_20231201.xlsx', 'Rec_CH_20231202.xlsx', 'Rec_CH_20231203.xlsx', 'Rec_CH_20231204.xlsx', 'Rec_CH_20231205.xlsx', 'Rec_CH_20231206.xlsx', 'Rec_CH_20231207.xlsx', 'Rec_CH_20231208.xlsx', 'Rec_CH_20231209.xlsx', 'Rec_CH_20231210.xlsx', 'Rec_CH_20231211.xlsx', 'Rec_CH_20231212.xlsx', 'Rec_CH_20231213.xlsx', 'Rec_CH_20231214.xlsx', 'Rec_CH_20231215.xlsx', 'Rec_CH_20231216.xlsx', 'Rec_CH_20231217.xlsx', 'Rec_CH_20231218.xlsx', 'Rec_CH_20231219.xlsx', 'Rec_CH_20231220.xlsx', 'Rec_CH_20231221.xlsx', 'Rec_CH_20231222.xlsx', 'Rec_CH_20231223.xlsx', 'Rec_CH_20231224.xlsx', 'Rec_CH_20231225.xlsx', 'Rec_CH_20231226.xlsx', 'Rec_CH_20231227.xlsx', 'Rec_CH_20231228.xlsx', 'Rec_CH_20231229.xlsx', 'Rec_CH_20231230.xlsx', 'Rec_CH_20231231.xlsx']

# %%
# Criar um endereço para cada ficheiro que está na pasta
files_xlsx = [path + '\\' + f for f in files if f[-4:] == 'xlsx']

# Identificar o nome dos ficheiros que estão a ser lidos no Python
print('Nome de todos os ficheiros lidos:', files)
# Out:
# Nome de todos os ficheiros lidos: ['Rec_CH_20231201.xlsx', 'Rec_CH_20231202.xlsx', 'Rec_CH_20231203.xlsx', 'Rec_CH_20231204.xlsx', 'Rec_CH_20231205.xlsx', 'Rec_CH_20231206.xlsx', 'Rec_CH_20231207.xlsx', 'Rec_CH_20231208.xlsx', 'Rec_CH_20231209.xlsx', 'Rec_CH_20231210.xlsx', 'Rec_CH_20231211.xlsx', 'Rec_CH_20231212.xlsx', 'Rec_CH_20231213.xlsx', 'Rec_CH_20231214.xlsx', 'Rec_CH_20231215.xlsx', 'Rec_CH_20231216.xlsx', 'Rec_CH_20231217.xlsx', 'Rec_CH_20231218.xlsx', 'Rec_CH_20231219.xlsx', 'Rec_CH_20231220.xlsx', 'Rec_CH_20231221.xlsx', 'Rec_CH_20231222.xlsx', 'Rec_CH_20231223.xlsx', 'Rec_CH_20231224.xlsx', 'Rec_CH_20231225.xlsx', 'Rec_CH_20231226.xlsx', 'Rec_CH_20231227.xlsx', 'Rec_CH_20231228.xlsx', 'Rec_CH_20231229.xlsx', 'Rec_CH_20231230.xlsx', 'Rec_CH_20231231.xlsx']

# %%
def read_xlsx_sheets(file_path, sheet_prefix):
    with pd.ExcelFile(file_path) as xlsx:
        df = pd.DataFrame()
        for sheet_name in xlsx.sheet_names:
            if sheet_name.startswith(sheet_prefix):
                sheet_data = xlsx.parse(sheet_name)
                sheet_data['Sheet'] = sheet_name  # Adiciona uma coluna com o nome da sheet
                print(sheet_name, '-', file_path)
                df = pd.concat([df, sheet_data], ignore_index=True)
    return df

# Lista de caminhos dos arquivos XLSX
files_xlsx = [path + '\\' + f for f in files if f[-4:] == 'xlsx']
sheet_prefix = "GL_Extract"

df = pd.DataFrame()

# Itere sobre os arquivos
for file_path in files_xlsx:
    file_name = os.path.basename(file_path)
    # Extrai a parte específica desejada do nome do arquivo
    source_column_value = file_name.split('.')[0]
    source_column_value = source_column_value.split('\\')[-1]
    file_data = read_xlsx_sheets(file_path, sheet_prefix)
    file_data['Source'] = source_column_value  # Adiciona uma coluna 'Source' ao DataFrame
    df = pd.concat([df, file_data], ignore_index=True)

display(df)
# Out:
# GL_Extract_20231201 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231201.xlsx
# GL_Extract_20231202 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231202.xlsx
# GL_Extract_20231203 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231203.xlsx
# GL_Extract_20231204 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231204.xlsx
# GL_Extract_20231205 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231205.xlsx
# GL_Extract_20231206 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231206.xlsx
# GL_Extract_20231207_1 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231207.xlsx
# GL_Extract_20231207_2 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231207.xlsx
# GL_Extract_20231207_3 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231207.xlsx
# GL_Extract_20231208 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231208.xlsx
# GL_Extract_20231209 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231209.xlsx
# GL_Extract_20231210 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231210.xlsx
# GL_Extract_20231211 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231211.xlsx
# GL_Extract_20231212 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231212.xlsx
# GL_Extract_20231213 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231213.xlsx
# GL_Extract_20231214 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231214.xlsx
# GL_Extract_20231215 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231215.xlsx
# GL_Extract_20231216 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231216.xlsx
# GL_Extract_20231217 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231217.xlsx
# GL_Extract_20231218 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231218.xlsx
# GL_Extract_20231219 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231219.xlsx
# GL_Extract_20231220_1 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231220.xlsx
# GL_Extract_20231220_2 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231220.xlsx
# GL_Extract_20231220_3 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231220.xlsx
# GL_Extract_20231221 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231221.xlsx
# GL_Extract_20231222 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231222.xlsx
# GL_Extract_20231223 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231223.xlsx
# GL_Extract_20231224 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231224.xlsx
# GL_Extract_20231225 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231225.xlsx
# GL_Extract_20231226 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231226.xlsx
# GL_Extract_20231227 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231227.xlsx
# GL_Extract_20231228 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231228.xlsx
# GL_Extract_20231229 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231229.xlsx
# GL_Extract_20231230_1 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231230.xlsx
# GL_Extract_20231230_2 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231230.xlsx
# GL_Extract_20231231 - C:\Users\BP00447\CTT - Correios de Portugal\Planeamento e Controlo - PCG_MIS\20. Project\Analytics\08. Rec_CH\Rec_CH_Montly_files\Rec_CH_20231231.xlsx
#                       TRANSACTION_ID OPERATION_ID  OP_CHARGEABLE  \
# 0                                NaN          NaN            NaN
# 1        MPA_20230029142033000000000          CH0            NaN
# 2        MPA_20230029142033000000000          CH0            NaN
# 3        MPA_20230029142034000000000          CH0            NaN
# 4        MPA_20230029142034000000000          CH0            NaN
# ...                              ...          ...            ...
# 9572599  MPA_20240000323522000000000          CH0            NaN
# 9572600  MPA_20230027170711000000000          CH0            NaN
# 9572601  MPA_20230027170711000000000          CH0            NaN
# 9572602  MPA_20230027170711000000000          CH0            NaN
# 9572603  MPA_20230027170711000000000          CH0            NaN
#
#         TRANSACTION_DATE  VALUE_DATE CURRENCY  EXCHANGE_RATE  \
# 0                    NaN         NaN      NaN            NaN
# 1             01.12.2023  16.10.2023      EUR            1.0
# 2             01.12.2023  16.10.2023      EUR            1.0
# 3             01.12.2023  16.10.2023      EUR            1.0
# 4             01.12.2023  16.10.2023      EUR            1.0
# ...                  ...         ...      ...            ...
# 9572599       03.01.2024  06.11.2023      EUR            1.0
# 9572600       03.01.2024  06.11.2023      EUR            1.0
# 9572601       03.01.2024  06.11.2023      EUR            1.0
# 9572602       03.01.2024  06.11.2023      EUR            1.0
# 9572603       03.01.2024  06.11.2023      EUR            1.0
#
#         DEBIT_CREDIT_FLAG  CUSTOMER_CODE  CUSTOMER_BANK_ACCOUNT  ...  EVENT  \
# 0                     NaN            NaN                    NaN  ...    NaN
# 1                       D            NaN                    NaN  ...  CH551
# 2                       C            NaN                    NaN  ...  CH551
# 3                       D            NaN                    NaN  ...  CH551
# 4                       C            NaN                    NaN  ...  CH551
# ...                   ...            ...                    ...  ...    ...
# 9572599                 D            NaN                    NaN  ...  CH207
# 9572600                 D            NaN                    NaN  ...  CH207
# 9572601                 C            NaN                    NaN  ...  CH207
# 9572602                 D            NaN                    NaN  ...  CH207
# 9572603                 C            NaN                    NaN  ...  CH207
#
#                                              DESCRIPTION.1  \
# 0                                                        0
# 1               COMISSOES PAGAS IMOB-COMISSAO-Ct:350009203
# 2               COMISSOES PAGAS IMOB-COMISSAO-Ct:350009203
# 3               COMISSOES PAGAS IMOB-COMISSAO-Ct:350009203
# 4               COMISSOES PAGAS IMOB-COMISSAO-Ct:350009203
# ...                                                    ...
# 9572599  JURO REMUNER CORRIDO-ATUAL-Ct:350009837       ...
# 9572600         JURO REMUNER CORRIDO-ANTERIOR-Ct:350009837
# 9572601         JURO REMUNER CORRIDO-ANTERIOR-Ct:350009837
# 9572602            JURO REMUNER CORRIDO-ATUAL-Ct:350009837
# 9572603            JURO REMUNER CORRIDO-ATUAL-Ct:350009837
#
#                     TRANSACTION_ID.1  TRANSACTION_DATE.1 VALUE_DATE.1  \
# 0                                  0                   0            0
# 1        MPA_20230029142033000000000          01.12.2023   16.10.2023
# 2        MPA_20230029142033000000000          01.12.2023   16.10.2023
# 3        MPA_20230029142034000000000          01.12.2023   16.10.2023
# 4        MPA_20230029142034000000000          01.12.2023   16.10.2023
# ...                              ...                 ...          ...
# 9572599  MPA_20240000323522000000000          03.01.2024   06.11.2023
# 9572600  MPA_20230027170711000000000          03.01.2024   06.11.2023
# 9572601  MPA_20230027170711000000000          03.01.2024   06.11.2023
# 9572602  MPA_20230027170711000000000          03.01.2024   06.11.2023
# 9572603  MPA_20230027170711000000000          03.01.2024   06.11.2023
#
#          AMOUNT.1                Sheet           Source                ….2  \
# 0            0.00  GL_Extract_20231201  Rec_CH_20231201                NaN
# 1         4800.00  GL_Extract_20231201  Rec_CH_20231201                NaN
# 2        -4800.00  GL_Extract_20231201  Rec_CH_20231201                NaN
# 3         4800.00  GL_Extract_20231201  Rec_CH_20231201                NaN
# 4        -4800.00  GL_Extract_20231201  Rec_CH_20231201                NaN
# ...           ...                  ...              ...                ...
# 9572599     33.17  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
# 9572600     29.48  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
# 9572601    -29.48  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
# 9572602     33.17  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
# 9572603    -33.17  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
#
#          Unnamed: 38
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 9572599          NaN
# 9572600          NaN
# 9572601          NaN
# 9572602          NaN
# 9572603          NaN
#
# [9572604 rows x 41 columns]

# %%
df = df.drop(columns = ['TRANSACTION_ID', 'OPERATION_ID', 'OP_CHARGEABLE', 'TRANSACTION_DATE', 'VALUE_DATE', 'CURRENCY', 'EXCHANGE_RATE', 'DEBIT_CREDIT_FLAG', 'CUSTOMER_CODE',
                        'CUSTOMER_BANK_ACCOUNT', 'NOMINAL_CODE', 'AMOUNT', 'TAX_CODE', 'TOTAL_AMOUNT', 'REFERENCE', 'BRANCH_CODE', 'DESCRIPTION', '5488434000', '5488434001', 'SOURCE', 'PROCESS', 'CONTRACT',
                        'EVENT', 'DESCRIPTION', 'TRANSACTION_ID', 'TRANSACTION_DATE', 'VALUE_DATE', 'AMOUNT', 'DESCRIPTION.1', 'TRANSACTION_ID.1', 'TRANSACTION_DATE.1', 'VALUE_DATE.1', 'AMOUNT.1', '…', '….1'])
df
# Out:
#          NOMINAL_CODE.1                           NOMINAL_CODE Description  \
# 0                   NaN                                                NaN
# 1          3.400002e+09  Despesas c/encargo dif-Cred Int-Hab-Imob.Comis...
# 2          5.488434e+09  Out.cont.reg-Sistema Crédito Habit.Com.Orig.Pagas
# 3          3.400002e+09  Despesas c/encargo dif-Cred Int-Hab-Imob.Comis...
# 4          5.488434e+09  Out.cont.reg-Sistema Crédito Habit.Com.Orig.Pagas
# ...                 ...                                                ...
# 9572599    7.904001e+09                   Juros-Crédito-Int-Part-Habitação
# 9572600    7.904001e+09                   Juros-Crédito-Int-Part-Habitação
# 9572601    3.304001e+09              Juros receber-Créd.Int-Part-Habitação
# 9572602    3.304001e+09              Juros receber-Créd.Int-Part-Habitação
# 9572603    7.904001e+09                   Juros-Crédito-Int-Part-Habitação
#
#          SAP_AMOUNT EVENTO             EVENTO DESCRITIVO      PROCESSO  \
# 0              0.00    NaN                           NaN           NaN
# 1           4800.00  CH551  Comissões Pagas Imobiliárias  5.020231e+11
# 2          -4800.00  CH551  Comissões Pagas Imobiliárias  5.020231e+11
# 3           4800.00  CH551  Comissões Pagas Imobiliárias  5.020231e+11
# 4          -4800.00  CH551  Comissões Pagas Imobiliárias  5.020231e+11
# ...             ...    ...                           ...           ...
# 9572599       33.17  CH207    Juro Remuneratório Corrido  5.020231e+11
# 9572600       29.48  CH207    Juro Remuneratório Corrido  5.020231e+11
# 9572601      -29.48  CH207    Juro Remuneratório Corrido  5.020231e+11
# 9572602       33.17  CH207    Juro Remuneratório Corrido  5.020231e+11
# 9572603      -33.17  CH207    Juro Remuneratório Corrido  5.020231e+11
#
#           CONTRATO                Sheet           Source                ….2  \
# 0              NaN  GL_Extract_20231201  Rec_CH_20231201                NaN
# 1        350009203  GL_Extract_20231201  Rec_CH_20231201                NaN
# 2        350009203  GL_Extract_20231201  Rec_CH_20231201                NaN
# 3        350009203  GL_Extract_20231201  Rec_CH_20231201                NaN
# 4        350009203  GL_Extract_20231201  Rec_CH_20231201                NaN
# ...            ...                  ...              ...                ...
# 9572599  350009837  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
# 9572600  350009837  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
# 9572601  350009837  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
# 9572602  350009837  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
# 9572603  350009837  GL_Extract_20231231  Rec_CH_20231231  Eventos múltiplos
#
#         Unnamed: 38
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 9572599         NaN
# 9572600         NaN
# 9572601         NaN
# 9572602         NaN
# 9572603         NaN
#
# [9572604 rows x 11 columns]

# %%
# Caminho base para salvar os arquivos
base_path = r'C:/Users/BP00447/CTT - Correios de Portugal/Planeamento e Controlo - PCG_MIS/20. Project/Analytics/08. Rec_CH/Output Python'

# Nome do arquivo a ser salvo
output_file_json = f"{base_path}/GL_EXTRACT.json"

# Perguntar ao usuário se tem certeza que deseja salvar o arquivo
confirmacao = input(f"Tem certeza que deseja salvar o arquivo '{output_file_json}'? (S/N): ").strip().lower()

if confirmacao == 's':
    # Salvar o DataFrame como arquivo JSON
    df.to_json(output_file_json, orient='records', lines=True)
    print(f"Arquivo JSON salvo em: {output_file_json}")
elif confirmacao == 'n':
    print("Arquivo não foi salvo.")
else:
    print("Opção inválida. Arquivo não foi salvo.")
# Out:
# Arquivo JSON salvo em: C:/Users/BP00447/CTT - Correios de Portugal/Planeamento e Controlo - PCG_MIS/20. Project/Analytics/08. Rec_CH/Output Python/GL_EXTRACT.json
