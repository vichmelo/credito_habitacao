# %% [markdown]
# # CONSOLIDAR FICHEIROS DIÁRIOS Rec_CH - GL_EXTRACT

# %%
import os
import pandas as pd

# %%
ano = input("Qual o ano e mês do ficheiro que deseja importar? (formato yyyy.mm)")
path = r'C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\' + ano
files = os.listdir(path)
df = pd.DataFrame()

print(files)
# Out:
# ['Rec_CH_20240401.xlsb', 'Rec_CH_20240402.xlsb', 'Rec_CH_20240403.xlsb', 'Rec_CH_20240404.xlsb', 'Rec_CH_20240405.xlsb', 'Rec_CH_20240406.xlsb', 'Rec_CH_20240407.xlsb', 'Rec_CH_20240408.xlsb', 'Rec_CH_20240409.xlsb', 'Rec_CH_20240410.xlsb', 'Rec_CH_20240411.xlsb', 'Rec_CH_20240412.xlsb', 'Rec_CH_20240413.xlsb', 'Rec_CH_20240414.xlsb', 'Rec_CH_20240415.xlsb', 'Rec_CH_20240416.xlsb', 'Rec_CH_20240417.xlsb', 'Rec_CH_20240418.xlsb', 'Rec_CH_20240419.xlsb', 'Rec_CH_20240420.xlsb', 'Rec_CH_20240421.xlsb', 'Rec_CH_20240422.xlsb', 'Rec_CH_20240423.xlsb', 'Rec_CH_20240424.xlsb', 'Rec_CH_20240425.xlsb']

# %%
# Criar um endereço para cada ficheiro que está na pasta
files_xlsb = [path + '\\' + f for f in files if f[-4:] == 'xlsb']

# Identificar o nome dos ficheiros que estão a ser lidos no Python
print('Nome de todos os ficheiros lidos:', files)
# Out:
# Nome de todos os ficheiros lidos: ['Rec_CH_20240401.xlsb', 'Rec_CH_20240402.xlsb', 'Rec_CH_20240403.xlsb', 'Rec_CH_20240404.xlsb', 'Rec_CH_20240405.xlsb', 'Rec_CH_20240406.xlsb', 'Rec_CH_20240407.xlsb', 'Rec_CH_20240408.xlsb', 'Rec_CH_20240409.xlsb', 'Rec_CH_20240410.xlsb', 'Rec_CH_20240411.xlsb', 'Rec_CH_20240412.xlsb', 'Rec_CH_20240413.xlsb', 'Rec_CH_20240414.xlsb', 'Rec_CH_20240415.xlsb', 'Rec_CH_20240416.xlsb', 'Rec_CH_20240417.xlsb', 'Rec_CH_20240418.xlsb', 'Rec_CH_20240419.xlsb', 'Rec_CH_20240420.xlsb', 'Rec_CH_20240421.xlsb', 'Rec_CH_20240422.xlsb', 'Rec_CH_20240423.xlsb', 'Rec_CH_20240424.xlsb', 'Rec_CH_20240425.xlsb']

# %%
def read_xlsb_sheets(file_path, sheet_prefix):
    with pd.ExcelFile(file_path, engine="pyxlsb") as xlsb:
        df = pd.DataFrame()
        
        for sheet_name in xlsb.sheet_names:
            if sheet_name.startswith(sheet_prefix):
                sheet_data = xlsb.parse(sheet_name)
                sheet_data['Sheet'] = sheet_name  # Adiciona uma coluna com o nome da sheet
                print(sheet_name, '-', file_path)
                df = pd.concat([df, sheet_data], ignore_index=True)
    return df

# Lista de caminhos dos arquivos XLSB
files_xlsb = [path + '\\' + f for f in files if f[-4:] == 'xlsb']
sheet_prefix = "MPA_GL_Extract" ############################ VERIFICAR SE O NOME DA SHEET É ESTE OU OUTRO #######################
##sheet_prefix = "GL_Extract"

df = pd.DataFrame()

# Itere sobre os arquivos
for file_path in files_xlsb:
    file_name = os.path.basename(file_path)
    # Extrai a parte específica desejada do nome do arquivo
    source_column_value = file_name.split('.')[0]
    source_column_value = source_column_value.split('\\')[-1]
    file_data = read_xlsb_sheets(file_path, sheet_prefix)
    file_data['Source'] = source_column_value  # Adiciona uma coluna 'Source' ao DataFrame
    df = pd.concat([df, file_data], ignore_index=True)

display(df)
# Out:
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240401.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240402.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240403.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240404.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240405.xlsb
# MPA_GL_Extract_1 - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240406.xlsb
# MPA_GL_Extract_2 - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240406.xlsb
# MPA_GL_Extract_3 - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240406.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240407.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240408.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240409.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240410.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240411.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240412.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240413.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240414.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240415.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240416.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240417.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240418.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240419.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240420.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240421.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240422.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240423.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240424.xlsb
# MPA_GL_Extract - C:\Users\BP00447\OneDrive - CTT - Correios de Portugal\General\\2024.04\Rec_CH_20240425.xlsb
#                       TRANSACTION_ID OPERATION_ID  OP_CHARGEABLE  \
# 0                                NaN          NaN            NaN
# 1        MPA_20240009791628000000000          CH0            NaN
# 2        MPA_20240009791628000000000          CH0            NaN
# 3        MPA_20240009791629000000000          CH0            NaN
# 4        MPA_20240009791629000000000          CH0            NaN
# ...                              ...          ...            ...
# 4206982  MPA_20240011653776000000000          CH0            NaN
# 4206983  MPA_20240011653777000000000          CH0            NaN
# 4206984  MPA_20240011653777000000000          CH0            NaN
# 4206985  MPA_20240011653777000000000          CH0            NaN
# 4206986  MPA_20240011653777000000000          CH0            NaN
#
#         TRANSACTION_DATE  VALUE_DATE CURRENCY  EXCHANGE_RATE  \
# 0                    NaN         NaN      NaN            NaN
# 1             01.04.2024  25.03.2024      EUR            1.0
# 2             01.04.2024  25.03.2024      EUR            1.0
# 3             01.04.2024  25.03.2024      EUR            1.0
# 4             01.04.2024  25.03.2024      EUR            1.0
# ...                  ...         ...      ...            ...
# 4206982       25.04.2024  25.04.2024      EUR            1.0
# 4206983       25.04.2024  25.04.2024      EUR            1.0
# 4206984       25.04.2024  25.04.2024      EUR            1.0
# 4206985       25.04.2024  25.04.2024      EUR            1.0
# 4206986       25.04.2024  25.04.2024      EUR            1.0
#
#         DEBIT_CREDIT_FLAG  CUSTOMER_CODE  CUSTOMER_BANK_ACCOUNT  ...  \
# 0                     NaN            NaN                    NaN  ...
# 1                       D            NaN                    NaN  ...
# 2                       C            NaN                    NaN  ...
# 3                       D            NaN                    NaN  ...
# 4                       C            NaN                    NaN  ...
# ...                   ...            ...                    ...  ...
# 4206982                 C            NaN                    NaN  ...
# 4206983                 D            NaN                    NaN  ...
# 4206984                 C            NaN                    NaN  ...
# 4206985                 D            NaN                    NaN  ...
# 4206986                 C            NaN                    NaN  ...
#
#           CONTRACT  EVENT                               DESCRIPTION.1  \
# 0              0xf    0xf                                           0
# 1        350009848  CH550  CUSTO CAMPANHA TRANS-COMISSAO-Ct:350009848
# 2        350009848  CH550  CUSTO CAMPANHA TRANS-COMISSAO-Ct:350009848
# 3        350009948  CH550  CUSTO CAMPANHA TRANS-COMISSAO-Ct:350009948
# 4        350009948  CH550  CUSTO CAMPANHA TRANS-COMISSAO-Ct:350009948
# ...            ...    ...                                         ...
# 4206982  350008425  CH207     JURO REMUNER CORRIDO-ATUAL-Ct:350008425
# 4206983  350010916  CH207  JURO REMUNER CORRIDO-ANTERIOR-Ct:350010916
# 4206984  350010916  CH207  JURO REMUNER CORRIDO-ANTERIOR-Ct:350010916
# 4206985  350010916  CH207     JURO REMUNER CORRIDO-ATUAL-Ct:350010916
# 4206986  350010916  CH207     JURO REMUNER CORRIDO-ATUAL-Ct:350010916
#
#                     TRANSACTION_ID.1 TRANSACTION_DATE.1  VALUE_DATE.1  \
# 0                                  0                  0             0
# 1        MPA_20240009791628000000000         01.04.2024    25.03.2024
# 2        MPA_20240009791628000000000         01.04.2024    25.03.2024
# 3        MPA_20240009791629000000000         01.04.2024    25.03.2024
# 4        MPA_20240009791629000000000         01.04.2024    25.03.2024
# ...                              ...                ...           ...
# 4206982  MPA_20240011653776000000000         25.04.2024    25.04.2024
# 4206983  MPA_20240011653777000000000         25.04.2024    25.04.2024
# 4206984  MPA_20240011653777000000000         25.04.2024    25.04.2024
# 4206985  MPA_20240011653777000000000         25.04.2024    25.04.2024
# 4206986  MPA_20240011653777000000000         25.04.2024    25.04.2024
#
#         AMOUNT.1                         ….2           Sheet           Source
# 0           0.00                           -  MPA_GL_Extract  Rec_CH_20240401
# 1         521.98  Trf diferimentos múltiplas  MPA_GL_Extract  Rec_CH_20240401
# 2        -521.98  Trf diferimentos múltiplas  MPA_GL_Extract  Rec_CH_20240401
# 3        1000.00  Trf diferimentos múltiplas  MPA_GL_Extract  Rec_CH_20240401
# 4       -1000.00  Trf diferimentos múltiplas  MPA_GL_Extract  Rec_CH_20240401
# ...          ...                         ...             ...              ...
# 4206982  -176.85                           -  MPA_GL_Extract  Rec_CH_20240425
# 4206983   319.44                           -  MPA_GL_Extract  Rec_CH_20240425
# 4206984  -319.44                           -  MPA_GL_Extract  Rec_CH_20240425
# 4206985   331.27                           -  MPA_GL_Extract  Rec_CH_20240425
# 4206986  -331.27                           -  MPA_GL_Extract  Rec_CH_20240425
#
# [4206987 rows x 40 columns]

# %%
df = df.drop(columns = ['TRANSACTION_ID', 'OPERATION_ID', 'OP_CHARGEABLE', 'TRANSACTION_DATE', 'VALUE_DATE', 'CURRENCY', 'EXCHANGE_RATE', 'DEBIT_CREDIT_FLAG', 'CUSTOMER_CODE',
                        'CUSTOMER_BANK_ACCOUNT', 'NOMINAL_CODE', 'AMOUNT', 'TAX_CODE', 'TOTAL_AMOUNT', 'REFERENCE', 'BRANCH_CODE', 'DESCRIPTION', '5488434000', '5488434001', 'SOURCE', 'PROCESS', 'CONTRACT',
                        'EVENT', 'DESCRIPTION', 'TRANSACTION_ID', 'TRANSACTION_DATE', 'VALUE_DATE', 'AMOUNT', 'DESCRIPTION.1', 'TRANSACTION_ID.1', 'TRANSACTION_DATE.1', 'VALUE_DATE.1', 'AMOUNT.1', '…', '….1'])
df
# Out:
#          NOMINAL_CODE.1                           NOMINAL_CODE Description  \
# 0                   NaN                                               0x2a
# 1          3.400002e+09   Despesas c/encargo dif-Cred Int-Hab-Campanha Trf
# 2          5.488434e+09  Out.cont.reg-Sistema Crédito Habit.Com.Orig.Pagas
# 3          3.400002e+09   Despesas c/encargo dif-Cred Int-Hab-Campanha Trf
# 4          5.488434e+09  Out.cont.reg-Sistema Crédito Habit.Com.Orig.Pagas
# ...                 ...                                                ...
# 4206982    7.904001e+09                   Juros-Crédito-Int-Part-Habitação
# 4206983    7.904001e+09                   Juros-Crédito-Int-Part-Habitação
# 4206984    3.304001e+09              Juros receber-Créd.Int-Part-Habitação
# 4206985    3.304001e+09              Juros receber-Créd.Int-Part-Habitação
# 4206986    7.904001e+09                   Juros-Crédito-Int-Part-Habitação
#
#          SAP_AMOUNT EVENTO              EVENTO DESCRITIVO      PROCESSO  \
# 0              0.00    0xf                            0xf           0xf
# 1            521.98  CH550  Custo Campanha Transferências  502023077910
# 2           -521.98  CH550  Custo Campanha Transferências  502023077910
# 3           1000.00  CH550  Custo Campanha Transferências  502023077731
# 4          -1000.00  CH550  Custo Campanha Transferências  502023077731
# ...             ...    ...                            ...           ...
# 4206982     -176.85  CH207     Juro Remuneratório Corrido  502022063364
# 4206983      319.44  CH207     Juro Remuneratório Corrido  502024084241
# 4206984     -319.44  CH207     Juro Remuneratório Corrido  502024084241
# 4206985      331.27  CH207     Juro Remuneratório Corrido  502024084241
# 4206986     -331.27  CH207     Juro Remuneratório Corrido  502024084241
#
#           CONTRATO                         ….2           Sheet  \
# 0              0xf                           -  MPA_GL_Extract
# 1        350009848  Trf diferimentos múltiplas  MPA_GL_Extract
# 2        350009848  Trf diferimentos múltiplas  MPA_GL_Extract
# 3        350009948  Trf diferimentos múltiplas  MPA_GL_Extract
# 4        350009948  Trf diferimentos múltiplas  MPA_GL_Extract
# ...            ...                         ...             ...
# 4206982  350008425                           -  MPA_GL_Extract
# 4206983  350010916                           -  MPA_GL_Extract
# 4206984  350010916                           -  MPA_GL_Extract
# 4206985  350010916                           -  MPA_GL_Extract
# 4206986  350010916                           -  MPA_GL_Extract
#
#                   Source
# 0        Rec_CH_20240401
# 1        Rec_CH_20240401
# 2        Rec_CH_20240401
# 3        Rec_CH_20240401
# 4        Rec_CH_20240401
# ...                  ...
# 4206982  Rec_CH_20240425
# 4206983  Rec_CH_20240425
# 4206984  Rec_CH_20240425
# 4206985  Rec_CH_20240425
# 4206986  Rec_CH_20240425
#
# [4206987 rows x 10 columns]

# %%
# Caminho base para salvar os arquivos
base_path = r'C:/Users/BP00447/CTT - Correios de Portugal/Planeamento e Controlo - PCG_MIS/20. Project/Analytics/08. Rec_CH/Output Python'

# Nome do arquivo a ser salvo
output_file_json = f"{base_path}/GL_EXTRACT_" + ano + ".json"

# Perguntar ao usuário se tem certeza que deseja salvar o arquivo
confirmacao = input(f"Tem certeza que deseja salvar o arquivo '{output_file_json}'? (S/N): ").strip().lower()

if confirmacao == 's':
    # Salvar o DataFrame como arquivo JSON
    df.to_json(output_file_json, orient='records', lines=True)
    print(f"Arquivo JSON salvo em: {output_file_json}")
elif confirmacao == 'n':
    print("Arquivo não foi salvo.")
else:
    print("Opção inválida. Arquivo não foi salvo.")
# Out:
# Arquivo JSON salvo em: C:/Users/BP00447/CTT - Correios de Portugal/Planeamento e Controlo - PCG_MIS/20. Project/Analytics/08. Rec_CH/Output Python/GL_EXTRACT_2024.04.json
